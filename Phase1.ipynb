# %% [markdown]
# <a href="https://colab.research.google.com/github/1FATIMAH1/Hospital-Database-System-KFSH/blob/main/Phase1.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# IT326 – Data Mining Project
## Phase 1: Data Selection

Dataset: Student Performance Factors


## Project Goal

The goal of this project is to analyze student performance and the factors that affect exam results.

This project includes:
- Classification using Exam_Score as the class label
- Clustering students based on similar characteristics


## Dataset Source

The dataset was obtained from Kaggle:
https://www.kaggle.com/datasets/lainguyn123/student-performance-factors
# Out:
#   File "/tmp/ipython-input-3191727263.py", line 4
#     Dataset: Student Performance Factors
#                      ^
# SyntaxError: invalid syntax

# %%
import pandas as pd
url = "https://raw.githubusercontent.com/leeno-ob/IT326-project/refs/heads/main/Dataset/Raw_dataset.csv"
df = pd.read_csv(url)

# Number and data types of attributes
print("Number of attributes (features):", df.shape[1])
print("\nData types of attributes:\n")
print(df.dtypes)

# Number of objects (records)
print("\nNumber of objects (instances/records):", df.shape[0])

# Class label information
class_label = "Exam_Score"
print("\nClass label:", class_label)
print("\nCounts for each value in the class label:\n")
print(df[class_label].value_counts())

# Print sample of raw dataset (as in slides)
df.head()
